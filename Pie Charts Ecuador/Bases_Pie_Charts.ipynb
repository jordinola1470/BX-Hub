# %%
import pandas as pd
import numpy as np
import os
import datetime

# %%
path = r'D:\Trabajo\Barómetro\BX\Web Scraping\Pie Charts Ecuador\Historico hasta enero 26 2022' + '\\'

# %%
df = pd.read_excel(path + "archivo_0.xlsx", skiprows=9)
df
# Out:
#             all  all.1
# 0  Integración     583
# 1      Trabajo     455
# 2        Salud     271
# 3    Seguridad    1353
# 4     Educación    247
# 5    Xenofobia     449

# %%
df.rename(columns= {"all": "Categoria", "all.1": "Volumen"}, inplace=True)

# %%
df
# Out:
#       Categoria  Volumen
# 0  Integración       583
# 1      Trabajo       455
# 2        Salud       271
# 3    Seguridad      1353
# 4     Educación      247
# 5    Xenofobia       449

# %%
df.sum()[1]
# Out:
# 3358

# %%
start_date = '2020-01-01' # YYYY-MM-DD
end_date = '2022-02-04' # PATTERN YYYY-MM-DD - YYYY-MM-DD
def next_week(fecha:str) -> str:
    nueva_fecha = datetime.datetime.strptime(fecha,'%Y-%m-%d').date()
    nueva_fecha = nueva_fecha + datetime.timedelta(days=7)
    return str(nueva_fecha)

def query_pie_chart(start_date: str, end_date: str) -> list:
    centinela = True
    retorno = list()
    two_weeks = next_week(next_week(start_date)) 
    n = 0
    while centinela == True:
        if n == 0:
            envio_range_fechas = start_date + " - " + two_weeks
            retorno.append(envio_range_fechas)
        else:
            start_date = two_weeks
            two_weeks = next_week(next_week(start_date))
            two_weeks_verif = datetime.datetime.strptime(two_weeks,'%Y-%m-%d').date()
            end_date_verif = datetime.datetime.strptime(end_date,'%Y-%m-%d').date()
            if int((end_date_verif - two_weeks_verif).days) < 0:
                centinela = False
            else:
                envio_range_fechas = start_date + " - " + two_weeks
                retorno.append(envio_range_fechas)
        n+=1
    return retorno
fechas = query_pie_chart(start_date, end_date)

# %%
final = pd.DataFrame()
for i in range(0,54):
    df = pd.read_excel(path + "archivo_" + str(i) + ".xlsx", skiprows=9)
    df.rename(columns= {"all": "Categoria", "all.1": "Volumen"}, inplace=True)
    dato = {'Categoria': 'Total', 'Volumen': df.sum()[1]}
    df = df.append(dato, ignore_index=True)
    df["Rango Fecha"] = fechas[i]
    final = final.append(df)

# %%
final
# Out:
#        Categoria  Volumen              Rango Fecha
# 0   Integración       583  2020-01-01 - 2020-01-15
# 1       Trabajo       455  2020-01-01 - 2020-01-15
# 2         Salud       271  2020-01-01 - 2020-01-15
# 3     Seguridad      1353  2020-01-01 - 2020-01-15
# 4      Educación      247  2020-01-01 - 2020-01-15
# ..           ...      ...                      ...
# 2         Salud       653  2022-01-12 - 2022-01-26
# 3     Seguridad      2006  2022-01-12 - 2022-01-26
# 4      Educación      172  2022-01-12 - 2022-01-26
# 5     Xenofobia       749  2022-01-12 - 2022-01-26
# 2021-09-08 - 2021-09-22      361        500
# 2021-09-22 - 2021-10-06      382       1183
# 2021-10-06 - 2021-10-20      350       1128
# 2021-10-20 - 2021-11-03      491        598
# 2021-11-03 - 2021-11-17      303        596
# 2021-11-17 - 2021-12-01      434        841
# 2021-12-01 - 2021-12-15      656        541
# 2021-12-15 - 2021-12-29     1430        546
# 2021-12-29 - 2022-01-12      461        673
# 2022-01-12 - 2022-01-26      784        749

# %%
melteddf.columns = melteddf.columns.droplevel()
melteddf.head(5)
# Out:
# Categoria                Educación  Integración   Salud   Seguridad   Total  \
# Rango Fecha
# 2020-01-01 - 2020-01-15        247           583     271        1353   3358
# 2020-01-15 - 2020-01-29        253           931     371        2953   6112
# 2020-01-29 - 2020-02-12        419          1694     334        9395  15686
# 2020-02-12 - 2020-02-26        365          1281     416        3329   7260
# 2020-02-26 - 2020-03-11        200           629     651        1755   4140
#
# Categoria                Trabajo   Xenofobia
# Rango Fecha
# 2020-01-01 - 2020-01-15       455         449
# 2020-01-15 - 2020-01-29      1048         556
# 2020-01-29 - 2020-02-12       976        2868
# 2020-02-12 - 2020-02-26       555        1314
# 2020-02-26 - 2020-03-11       318         587

# %%
columns_list = melteddf.columns
columns_list = columns_list.drop('Total')
for i in range(len(columns_list)):
    texto = str(columns_list[i]).strip()
    melteddf[texto + " %"] = melteddf[columns_list[i]]/melteddf['Total']
melteddf.head(5)
# Out:
# Categoria                Educación  Integración   Salud   Seguridad   Total  \
# Rango Fecha
# 2020-01-01 - 2020-01-15        247           583     271        1353   3358
# 2020-01-15 - 2020-01-29        253           931     371        2953   6112
# 2020-01-29 - 2020-02-12        419          1694     334        9395  15686
# 2020-02-12 - 2020-02-26        365          1281     416        3329   7260
# 2020-02-26 - 2020-03-11        200           629     651        1755   4140
#
# Categoria                Trabajo   Xenofobia   Educación %  Integración %  \
# Rango Fecha
# 2020-01-01 - 2020-01-15       455         449     0.073556       0.173615
# 2020-01-15 - 2020-01-29      1048         556     0.041394       0.152323
# 2020-01-29 - 2020-02-12       976        2868     0.026712       0.107994
# 2020-02-12 - 2020-02-26       555        1314     0.050275       0.176446
# 2020-02-26 - 2020-03-11       318         587     0.048309       0.151932
#
# Categoria                 Salud %  Seguridad %  Trabajo %  Xenofobia %
# Rango Fecha
# 2020-01-01 - 2020-01-15  0.080703     0.402918   0.135497     0.133711
# 2020-01-15 - 2020-01-29  0.060700     0.483148   0.171466     0.090969
# 2020-01-29 - 2020-02-12  0.021293     0.598942   0.062221     0.182838
# 2020-02-12 - 2020-02-26  0.057300     0.458540   0.076446     0.180992
# 2020-02-26 - 2020-03-11  0.157246     0.423913   0.076812     0.141787

# %%
melteddf.to_excel("Histórico_Pie_Charts.xlsx")
